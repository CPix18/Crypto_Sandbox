# %%
import requests
import json

# Create parameterized url
request_url = "https://data-api.defipulse.com/api/v1/defipulse/api/MarketData"

# Submit request and format output
response_data = requests.get(request_url).json()
print(json.dumps(response_data, indent=4))

# Select fact 
response_data
# Out:
# {
#     "All": {
#         "total": 11268531511.593971,
#         "dominance_name": "Uniswap",
#         "dominance_value": 2694161585,
#         "value": {
#             "total": {
#                 "USD": {
#                     "value": 11268531511.593971
#                 },
#                 "ETH": {
#                     "value": 9176525.139170248
#                 },
#                 "BTC": {
#                     "value": 163750.33494899998
#                 }
#             },
#             "balance": {
#                 "ERC20": {
#                     "DAI": {
#                         "value": 930312056.981945
#                     }
#                 }
#             },
#             "tvl": {
#                 "ETH": {
#                     "value": 31233565.443925872
#                 }
#             }
#         },
#         "dominance_pct": 23.908719447853784
#     },
#     "Lending": {
#         "total": 3889203999,
#         "dominance_name": "Maker",
#         "dominance_value": 1938003335,
#         "value": {
#             "total": {
#                 "USD": {
#                     "value": 3889203999
#                 },
#                 "ETH": {
#                     "value": 4019568.70145055
#                 },
#                 "BTC": {
#                     "value": 15528.145007430001
#                 }
#             },
#             "balance": {
#                 "ERC20": {
#                     "DAI": {
#                         "value": 588680722.7246996
#                     }
#                 }
#             },
#             "tvl": {
#                 "ETH": {
#                     "value": 10614929.444035046
#                 }
#             }
#         },
#         "dominance_pct": 49.83033380348018
#     },
#     "DEXes": {
#         "total": 4267666167,
#         "dominance_name": "Uniswap",
#         "dominance_value": 2694161585,
#         "value": {
#             "total": {
#                 "USD": {
#                     "value": 4267666167
#                 },
#                 "ETH": {
#                     "value": 4407913.739464299
#                 },
#                 "BTC": {
#                     "value": 68293.57529371
#                 }
#             },
#             "balance": {
#                 "ERC20": {
#                     "DAI": {
#                         "value": 281395824.84558254
#                     }
#                 }
#             },
#             "tvl": {
#                 "ETH": {
#                     "value": 11647878.400065504
#                 }
#             }
#         },
#         "dominance_pct": 63.12962353599201
#     },
#     "Derivatives": {
#         "total": 643646509,
#         "dominance_name": "Synthetix",
#         "dominance_value": 563797510,
#         "value": {
#             "total": {
#                 "USD": {
#                     "value": 643646509
#                 },
#                 "ETH": {
#                     "value": 202200.0139603976
#                 },
#                 "BTC": {
#                     "value": 0
#                 }
#             },
#             "balance": {
#                 "ERC20": {
#                     "DAI": {
#                         "value": 394089.036004
#                     }
#                 }
#             },
#             "tvl": {
#                 "ETH": {
#                     "value": 1756725.0989382896
#                 }
#             }
#         },
#         "dominance_pct": 87.59427762234627
#     },
#     "Payments": {
#         "total": 143137919,
#         "dominance_name": "Flexa",
#         "dominance_value": 125489233,
#         "value": {
#             "total": {
#                 "USD": {
#                     "value": 143137919
#                 },
#                 "ETH": {
#                     "value": 1538.890184
#                 },
#                 "BTC": {
#                     "value": 1054.687187
#                 }
#             },
#             "balance": {
#                 "ERC20": {
#                     "DAI": {
#                         "value": 2893398.7472417234
#                     }
#                 }
#             },
#             "tvl": {
#                 "ETH": {
#                     "value": 390670.92169546115
#                 }
#             }
#         },
#         "dominance_pct": 87.67015328761346
#     },
#     "Assets": {
#         "total": 2500011449,
#         "dominance_name": "WBTC",
#         "dominance_value": 1270539943,
#         "value": {
#             "total": {
#                 "USD": {
#                     "value": 2500011449
#                 },
#                 "ETH": {
#                     "value": 545303.794111
#                 },
#                 "BTC": {
#                     "value": 139878.32059
#                 }
#             },
#             "balance": {
#                 "ERC20": {
#                     "DAI": {
#                         "value": 56948021.628417
#                     }
#                 }
#             },
#             "tvl": {
#                 "ETH": {
#                     "value": 6823361.579191571
#                 }
#             }
#         },
#         "dominance_pct": 50.82136497847694
#     }
# }
# {'All': {'total': 11268531511.593971,
#   'dominance_name': 'Uniswap',
#   'dominance_value': 2694161585,
#   'value': {'total': {'USD': {'value': 11268531511.593971},
#     'ETH': {'value': 9176525.139170248},
#     'BTC': {'value': 163750.33494899998}},
#    'balance': {'ERC20': {'DAI': {'value': 930312056.981945}}},
#    'tvl': {'ETH': {'value': 31233565.443925872}}},
#   'dominance_pct': 23.908719447853784},
#  'Lending': {'total': 3889203999,
#   'dominance_name': 'Maker',
#   'dominance_value': 1938003335,
#   'value': {'total': {'USD': {'value': 3889203999},
#     'ETH': {'value': 4019568.70145055},
#     'BTC': {'value': 15528.145007430001}},
#    'balance': {'ERC20': {'DAI': {'value': 588680722.7246996}}},
#    'tvl': {'ETH': {'value': 10614929.444035046}}},
#   'dominance_pct': 49.83033380348018},
#  'DEXes': {'total': 4267666167,
#   'dominance_name': 'Uniswap',
#   'dominance_value': 2694161585,
#   'value': {'total': {'USD': {'value': 4267666167},
#     'ETH': {'value': 4407913.739464299},
#     'BTC': {'value': 68293.57529371}},
#    'balance': {'ERC20': {'DAI': {'value': 281395824.84558254}}},
#    'tvl': {'ETH': {'value': 11647878.400065504}}},
#   'dominance_pct': 63.12962353599201},
#  'Derivatives': {'total': 643646509,
#   'dominance_name': 'Synthetix',
#   'dominance_value': 563797510,
#   'value': {'total': {'USD': {'value': 643646509},
#     'ETH': {'value': 202200.0139603976},
#     'BTC': {'value': 0}},
#    'balance': {'ERC20': {'DAI': {'value': 394089.036004}}},
#    'tvl': {'ETH': {'value': 1756725.0989382896}}},
#   'dominance_pct': 87.59427762234627},
#  'Payments': {'total': 143137919,
#   'dominance_name': 'Flexa',
#   'dominance_value': 125489233,
#   'value': {'total': {'USD': {'value': 143137919},
#     'ETH': {'value': 1538.890184},
#     'BTC': {'value': 1054.687187}},
#    'balance': {'ERC20': {'DAI': {'value': 2893398.7472417234}}},
#    'tvl': {'ETH': {'value': 390670.92169546115}}},
#   'dominance_pct': 87.67015328761346},
#  'Assets': {'total': 2500011449,
#   'dominance_name': 'WBTC',
#   'dominance_value': 1270539943,
#   'value': {'total': {'USD': {'value': 2500011449},
#     'ETH': {'value': 545303.794111},
#     'BTC': {'value': 139878.32059}},
#    'balance': {'ERC20': {'DAI': {'value': 56948021.628417}}},
#    'tvl': {'ETH': {'value': 6823361.579191571}}},
#   'dominance_pct': 50.82136497847694}}
